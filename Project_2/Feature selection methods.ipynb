# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import balanced_accuracy_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SequentialFeatureSelector, SelectFromModel
from sklearn.linear_model import LassoCV
from boruta import BorutaPy

# %% [markdown]
# # Artificial dataset

# %% [markdown]
# # Data Preparation

# %%
x_train=pd.read_csv("data/artificial_train.data",header=None, sep=" ")

x_train=x_train.drop(columns=[500])

y_train=pd.read_csv("data/artificial_train.labels",header=None, sep=" ")

y_train=y_train.to_numpy().reshape(-1)

x_val=pd.read_csv("data/artificial_valid.data",header=None, sep=" ").iloc[:,:500]

scaler = MinMaxScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_val=scaler.transform(x_val)

# %% [markdown]
# # Final classification and estimated error

# %% [markdown]
# ## Boruta algorithm

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=1, max_iter = 5000)
feat_selector.fit(x_train, y_train)
x_boruta = feat_selector.transform(x_train)
x_val_boruta = feat_selector.transform(x_val)
# Out:
# Iteration: 	1 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	2 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	3 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	4 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	5 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	6 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	7 / 5000
# Confirmed: 	0
# Tentative: 	500
# Rejected: 	0
# Iteration: 	8 / 5000
# Confirmed: 	0
# Tentative: 	22
# Rejected: 	478
# Iteration: 	9 / 5000
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	478
# Iteration: 	10 / 5000
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	478
# Iteration: 	11 / 5000
# Confirmed: 	17
# Tentative: 	5
# Rejected: 	478
# Iteration: 	12 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	13 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	14 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	15 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	16 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	17 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	18 / 5000
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	478
# Iteration: 	19 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	20 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	21 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	22 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	23 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	24 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	25 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	26 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	27 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	28 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	29 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	30 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	31 / 5000
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	478
# Iteration: 	32 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	33 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	34 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	35 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	36 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	37 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	38 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	39 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	40 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	41 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	42 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	43 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	44 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	45 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	46 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	47 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	48 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	49 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	50 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	51 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	52 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	53 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	54 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	55 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	56 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	57 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	58 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	59 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	60 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	61 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	62 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	63 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	64 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	65 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	66 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	67 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	68 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	69 / 5000
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	479
# Iteration: 	70 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	71 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	72 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	73 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	74 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	75 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	76 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	77 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	78 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	79 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	80 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	81 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	82 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	83 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	84 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	85 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	86 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	87 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	88 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	89 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	90 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	91 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	92 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	93 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	94 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	95 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	96 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	97 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	98 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	99 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	100 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	101 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	102 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	103 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	104 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	105 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	106 / 5000
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	479
# Iteration: 	107 / 5000
# Confirmed: 	21
# Tentative: 	0
# Rejected: 	479
#
#
# BorutaPy finished running.
#
# Iteration: 	108 / 5000
# Confirmed: 	21
# Tentative: 	0
# Rejected: 	479

# %%
np.where(feat_selector.support_)[0] + 1
# Out:
# array([ 11,  29,  49,  65, 106, 129, 154, 205, 242, 282, 319, 337, 339,
#        379, 434, 443, 452, 454, 473, 476, 494], dtype=int64)

# %%
feat_selector.ranking_
# Out:
# array([437, 267, 362, 448,   8, 118,  91, 469, 396, 445,   1, 262,  97,
#         23, 404, 227, 257, 236, 130, 300, 441, 377, 443, 385, 209, 206,
#         92, 270,   1, 145, 398, 244,  47, 143, 280, 292, 201, 358,  21,
#        473, 424, 262, 134,  51,  48, 250,  86, 224,   1, 134, 293, 110,
#        242, 328, 119,  25,  32, 272, 311, 103,  71, 293, 303, 430,   1,
#        216, 160, 319, 119, 422, 349, 352, 241,  57, 115, 278, 402, 114,
#        212, 113, 399,  87, 176, 214, 128, 125, 427, 279, 232, 181, 478,
#        231, 366, 345, 369, 207, 435, 248, 203, 117, 191, 436, 397, 266,
#        150,   1,  61, 265, 404, 110, 322,  76, 428, 434, 210, 284,  37,
#        286, 290,  38, 455, 169, 426, 374, 228, 132, 367, 128,   1,  55,
#         55,  74, 410, 440, 290, 168,  12,  44, 382, 147,  92, 320, 437,
#        442, 219, 340, 313,  46, 275,  20, 149, 354,  75,   1, 467, 219,
#         59, 339, 156, 148, 272, 219, 276, 258, 166, 296, 471, 341, 466,
#        392, 305, 102, 222, 459, 242,  71, 381,  84, 400, 288,  50, 255,
#        252, 325,  22, 337, 348, 325, 133, 429, 264, 123, 167, 186, 332,
#        389, 330, 351, 461,  17, 194, 254, 105, 401,   1, 432, 238, 296,
#        331, 158, 375,  26, 302, 136, 378, 140, 328,  53, 322, 453, 212,
#        170, 317, 201, 101, 341,  95, 463, 480, 188, 394, 338, 382, 253,
#        176, 125, 325, 455,  45, 416, 224,   1, 393,  36,  31, 110, 178,
#        465, 410, 406, 127,  90, 454, 358, 430, 180, 258, 282, 371,  66,
#        240, 418, 161, 255,  98, 192, 304, 250, 282, 163, 186, 154, 356,
#        173, 433, 313, 477,  82,   6, 145, 469,   1,   9, 458,  65,  28,
#         16, 125, 472, 234, 195, 332, 223, 407,  63, 131,  11, 360,  19,
#        316,  68,  89, 203,  27, 244, 210,  94, 307, 174, 360,  40, 407,
#        320, 274, 174, 315, 375,  42,   1, 106, 363,  99, 418,  24, 385,
#        462, 110, 388, 308,  39, 171, 189, 460, 268,   6, 345,   1, 153,
#          1, 196, 121, 276, 299,  33, 345, 414, 198,  43,   6,   2, 418,
#        143, 201, 403,  85, 380, 190, 468,  77, 106, 369,  80, 137,  34,
#        446, 234, 234,  83, 355, 318,  58, 281, 151, 335,  70, 216, 443,
#         30,   1, 139, 343, 298, 110, 226,  48, 423, 162, 474, 249,  53,
#        457, 151, 447, 155, 451, 345, 372, 121, 353, 450, 394, 367, 475,
#        156, 478, 412, 116, 452, 138, 246,  17,  13,  59,  79, 196, 285,
#        261,   9, 309,  66,  96, 336, 270, 476,  15,  69, 391, 205, 378,
#        389,  29,   3, 140,   1, 193, 363,  81, 287, 306, 418, 309, 183,
#          1, 230,  64, 184, 365, 387, 142, 334, 296,   1, 409,   1, 181,
#          4, 186,  35,  87, 236, 349, 384, 260,  77, 208, 164, 219,  41,
#        104, 328, 268, 239,   1, 464, 415,   1, 424, 172,  53, 412, 247,
#         14, 421, 215, 158, 439, 290, 198, 179, 373,  73, 448, 301,   1,
#         62, 164, 100, 229, 311, 357])

# %% [markdown]
# ## PCA

# %%
pca = PCA(n_components=8)

pca.fit(x_boruta)

x_train=pca.transform(x_boruta)
x_val=pca.transform(x_val_boruta)

# %% [markdown]
# ## Performance

# %%
forest=RandomForestClassifier().fit(x_train, y_train)

pred = forest.predict(x_train)

balanced_accuracy_score(y_train, pred)
# Out:
# 1.0

# %%
posterior_probs = forest.predict_proba(x_val)[:,1]

# %%
pd.DataFrame({'MATSZY': posterior_probs}).to_csv('MATSZY_artificial_prediction.txt', index = None)

# %% [markdown]
# ## 5-fold cross-validation

# %%
acc_reg=[0 for x in range(5)]
acc_forest=[0 for x in range(5)]
for i in range(5):
    mask = np.zeros(x_train.shape[0], dtype=bool)
    mask[i::5] = True

    x_test = x_train[mask]
    x_fold = x_train[~mask]
    
    y_test = y_train[mask]
    y_fold = y_train[~mask]
    
    reg = LogisticRegression().fit(x_fold, y_fold)
    pred = reg.predict(x_test)
    acc_reg[i]=balanced_accuracy_score(y_test, pred)
    
    forest=RandomForestClassifier().fit(x_fold, y_fold)
    pred = forest.predict(x_test)
    acc_forest[i]=balanced_accuracy_score(y_test, pred)
print('Forest: ', acc_forest)
print('Logistic regression: ', acc_reg)
# Out:
# Forest:  [0.8282178590235463, 0.8525923330997898, 0.8344611528822055, 0.84998499849985, 0.8273486534470256]
# Logistic regression:  [0.5917901652498809, 0.5855269742768492, 0.6499999999999999, 0.6377387738773878, 0.6146132879897976]

# %%
sum(acc_forest)/5
# Out:
# 0.8385209993904834

# %% [markdown]
# # Different tests

# %% [markdown]
# # Univariate feature selection

# %%
x_train=pd.read_csv("data/artificial_train.data",header=None, sep=" ")

x_train=x_train.drop(columns=[500])

y_train=pd.read_csv("data/artificial_train.labels",header=None, sep=" ")

y_train=y_train.to_numpy().reshape(-1)

x_val=pd.read_csv("data/artificial_valid.data",header=None, sep=" ").iloc[:,:500]

scaler = MinMaxScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_val=scaler.transform(x_val)

# %%
kbest = SelectKBest(chi2, k=21)
kbest.fit(x_train, y_train)
x_kbest = kbest.transform(x_train)
vars_indexes = np.where(kbest.get_support())[0]
scores = kbest.scores_[vars_indexes]

# %%
kbest.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False])

# %%
pd.DataFrame({'variable': vars_indexes + 1, 'Univariate_selection': scores}).to_csv('Univariate_selection.csv')

# %% [markdown]
# ## Sequential feature selection

# %% [markdown]
# Sequential Feature Selection (is very slow) (lasso can be replaced with reg or forest)

# %%
lasso = LassoCV().fit(x_train, y_train)
importance = np.abs(lasso.coef_)

sfs_forward = SequentialFeatureSelector(lasso, n_features_to_select=8,
                                        direction='forward').fit(x_train, y_train)

sfs_forward.get_support()

x_train_lasso1=sfs_forward.transform(x_train)

# %%
lasso = LassoCV().fit(x_train, y_train)
importance = np.abs(lasso.coef_)
threshold = np.sort(importance)[-11] + 0.01
sfm = SelectFromModel(lasso, threshold=threshold).fit(x_train, y_train)
x_train_lasso=sfm.transform(x_train)

# %% [markdown]
# ## Removing features based on variance

# %%
sel = VarianceThreshold(threshold=0.025)
x_train_var=sel.fit_transform(x_train)
